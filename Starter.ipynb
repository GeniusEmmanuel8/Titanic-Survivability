# %% [markdown]
# Data Exploration of Titanic dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
gs = pd.read_csv('gender_submission.csv')
print (gs)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
tr = pd.read_csv('train.csv')
print(tr)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
te = pd.read_csv('test.csv')
print(te)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
tr.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(tr['Survived'])
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
count_survived_1 = (tr['Survived'] == 1).sum()

print(f"Number of people that survived: {count_survived_1 }")
# Out:
# Number of people that survived: 342

# %%
gs.columns
# Out:
# Index(['PassengerId', 'Survived'], dtype='object')

# %%
te.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
tr.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
subset_tr = tr[['Survived', 'Pclass', 'Sex', 'Age', 'Embarked']]

# %%
print(subset_tr)
# Out:
#      Survived  Pclass     Sex   Age Embarked
# 0           0       3    male  22.0        S
# 1           1       1  female  38.0        C
# 2           1       3  female  26.0        S
# 3           1       1  female  35.0        S
# 4           0       3    male  35.0        S
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0        S
# 887         1       1  female  19.0        S
# 888         0       3  female   NaN        S
# 889         1       1    male  26.0        C
# 890         0       3    male  32.0        Q
#
# [891 rows x 5 columns]

# %%
tr_1 = subset_tr[subset_tr['Survived']==1]
print (tr_1)
# Out:
#      Survived  Pclass     Sex    Age Embarked
# 1           1       1  female  38.00        C
# 2           1       3  female  26.00        S
# 3           1       1  female  35.00        S
# 8           1       3  female  27.00        S
# 9           1       2  female  14.00        C
# 10          1       3  female   4.00        S
# 11          1       1  female  58.00        S
# 15          1       2  female  55.00        S
# 17          1       2    male    NaN        S
# 19          1       3  female    NaN        C
# 21          1       2    male  34.00        S
# 22          1       3  female  15.00        Q
# 23          1       1    male  28.00        S
# 25          1       3  female  38.00        S
# 28          1       3  female    NaN        Q
# 31          1       1  female    NaN        C
# 32          1       3  female    NaN        Q
# 36          1       3    male    NaN        C
# 39          1       3  female  14.00        C
# ...

# %%
tr_2 = tr_1[tr_1['Sex'] == 'female']
print(tr_2)
# Out:
#      Survived  Pclass     Sex    Age Embarked
# 1           1       1  female  38.00        C
# 2           1       3  female  26.00        S
# 3           1       1  female  35.00        S
# 8           1       3  female  27.00        S
# 9           1       2  female  14.00        C
# 10          1       3  female   4.00        S
# 11          1       1  female  58.00        S
# 15          1       2  female  55.00        S
# 19          1       3  female    NaN        C
# 22          1       3  female  15.00        Q
# 25          1       3  female  38.00        S
# 28          1       3  female    NaN        Q
# 31          1       1  female    NaN        C
# 32          1       3  female    NaN        Q
# 39          1       3  female  14.00        C
# 43          1       2  female   3.00        C
# 44          1       3  female  19.00        Q
# 47          1       3  female    NaN        Q
# 52          1       1  female  49.00        C
# ...

# %%
count_survived_2 = (tr_2['Survived'] == 1).sum()

print(f"Number of people that survived and are female: {count_survived_2 }")
# Out:
# Number of people that survived and are female: 233

# %%
count_survived_1 = (tr['Survived'] == 1).sum()

print(f"Number of people that survived: {count_survived_1 }")
# Out:
# Number of people that survived: 342

# %%
fem_surv_rate = count_survived_2/count_survived_1
print (fem_surv_rate.round(2))
# Out:
# 0.68

# %%
tr_m = subset_tr[subset_tr['Sex'] == 'male']
print(tr_m)
# Out:
#      Survived  Pclass   Sex    Age Embarked
# 0           0       3  male  22.00        S
# 4           0       3  male  35.00        S
# 5           0       3  male    NaN        Q
# 6           0       1  male  54.00        S
# 7           0       3  male   2.00        S
# 12          0       3  male  20.00        S
# 13          0       3  male  39.00        S
# 16          0       3  male   2.00        Q
# 17          1       2  male    NaN        S
# 20          0       2  male  35.00        S
# 21          1       2  male  34.00        S
# 23          1       1  male  28.00        S
# 26          0       3  male    NaN        C
# 27          0       1  male  19.00        S
# 29          0       3  male    NaN        S
# 30          0       1  male  40.00        C
# 33          0       2  male  66.00        S
# 34          0       1  male  28.00        C
# 35          0       1  male  42.00        S
# 36          1       3  male    NaN        C
# ...

# %%
count_survived_3 = (tr_m['Survived'] == 1).sum()

print(f"Number of people that survived and are male: {count_survived_3 }")
# Out:
# Number of people that survived and are male: 109

# %%
men_surv_rate = count_survived_3/count_survived_1
print (men_surv_rate.round(2))
# Out:
# 0.32

# %%
survived_112 = fem_surv_rate > men_surv_rate
print(survived_112)
# Out:
# True

# %% [markdown]
# By comparing the men_surv_rate which represents the survival rate of men on the titanic to the fem_surv_rate which represents the survival rate of women on the titanic we can see that the survival rate amongst women was greater than that of men

# %%
tr_2.isnull().sum()
# Out:
# Survived     0
# Pclass       0
# Sex          0
# Age         36
# Embarked     2
# dtype: int64

# %%
tr_2.Age.isnull().sum()
# Out:
# 36

# %% [markdown]
# I am going to try different methods to figure out theh age range of those that survived, i am going to drop the, then i am going to replace missing values with the mean age.

# %% [markdown]
# # Drop missing values

# %%
#dropping missing values
dropped_tr_2 = tr_2.dropna()
dropped_tr_2.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# Embarked    0
# dtype: int64

# %% [markdown]
# # Replace missing values

# %%
max_age = tr_2['Age'].max()
print(max_age)
# Out:
# 63.0

# %%
min_age = tr_2['Age'].min()
print(min_age)
# Out:
# 0.75

# %%
mode_age = tr_2['Age'].mode()[0]
print(mode_age)
# Out:
# 24.0

# %%
pd.set_option('display.max_rows', None)
age_counts = tr_2['Age'].value_counts()
print(age_counts)
# Out:
# 24.00    14
# 22.00    10
# 30.00     9
# 35.00     8
# 18.00     8
# 36.00     7
# 19.00     7
# 33.00     6
# 16.00     5
# 17.00     5
# 29.00     5
# 28.00     5
# 31.00     5
# 4.00      5
# 27.00     5
# 40.00     5
# 34.00     4
# 50.00     4
# 38.00     4
# 23.00     4
# 15.00     4
# 5.00      4
# 21.00     4
# 39.00     4
# 14.00     3
# 58.00     3
# 45.00     3
# 42.00     3
# 48.00     3
# 54.00     3
# 26.00     3
# 0.75      2
# 52.00     2
# 13.00     2
# 2.00      2
# 25.00     2
# 44.00     2
# 41.00     2
# 32.00     2
# 1.00      2
# 49.00     2
# 63.00     2
# 60.00     1
# 6.00      1
# 47.00     1
# 62.00     1
# 43.00     1
# 51.00     1
# 53.00     1
# 55.00     1
# 3.00      1
# 32.50     1
# 7.00      1
# 8.00      1
# 56.00     1
# Name: Age, dtype: int64

# %%
median_age = tr_2['Age'].median()

# %%
print(median_age)
# Out:
# 28.0

# %%
bins = [0, 12, 18, 35, 50, 65]
labels = ['Child', 'Teen', 'Young Adult', 'Middle Aged', 'Senior']

# %%
tr_2 = tr_2.copy()
tr_2['Age_Group'] = pd.cut(tr_2['Age'], bins=bins, labels=labels)

# %%
print(tr_2['Age_Group'])
# Out:
# 1      Middle Aged
# 2      Young Adult
# 3      Young Adult
# 8      Young Adult
# 9             Teen
# 10           Child
# 11          Senior
# 15          Senior
# 19             NaN
# 22            Teen
# 25     Middle Aged
# 28             NaN
# 31             NaN
# 32             NaN
# 39            Teen
# 43           Child
# 44     Young Adult
# 47             NaN
# 52     Middle Aged
# 53     Young Adult
# 56     Young Adult
# 58           Child
# 61     Middle Aged
# 66     Young Adult
# 68            Teen
# 79     Young Adult
# 82             NaN
# 84            Teen
# 85     Young Adult
# 88     Young Adult
# 98     Young Adult
# 106    Young Adult
# 109            NaN
# 123    Young Adult
# 128            NaN
# 133    Young Adult
# 136    Young Adult
# 141    Young Adult
# 142    Young Adult
# 151    Young Adult
# 156           Teen
# 161    Middle Aged
# 166            NaN
# 172          Child
# 184          Child
# 186            NaN
# 190    Young Adult
# ...

# %%
Child_surv_count = (tr_2['Age_Group'] == 'Child').sum()
print(Child_surv_count)
Child_surv_rate = Child_surv_count/count_survived_2
a = Child_surv_rate.round(2)
print(a)
# Out:
# 19
# 0.08

# %%
Teen_surv_count = (tr_2['Age_Group'] == 'Teen').sum()
print(Teen_surv_count)
Teen_surv_rate = Teen_surv_count/count_survived_2
b = Teen_surv_rate.round(2)
print(b)
# Out:
# 27
# 0.12

# %%
Young_Adult_count = (tr_2['Age_Group'] == 'Young Adult').sum()
print(Young_Adult_count)
Young_Adult_rate = Young_Adult_count/count_survived_2
c = Young_Adult_rate.round(2)
print(c)
# Out:
# 94
# 0.4

# %%
middle_Aged_count = (tr_2['Age_Group'] == 'Middle Aged').sum()
print(middle_Aged_count)
middle_Aged_rate = middle_Aged_count/count_survived_2
d = middle_Aged_rate.round(2)
print(d)
# Out:
# 41
# 0.18

# %%
Senior_Aged_count = (tr_2['Age_Group'] == 'Senior').sum()
print(Senior_Aged_count)
Senior_Aged_rate = Senior_Aged_count/count_survived_2
e = Senior_Aged_rate.round(2)
print (e)
# Out:
# 16
# 0.07

# %% [markdown]
# From our findings above we can say that Young Adult women between the ages of 18 and 35 were the most likely to survive.

# %%
young_adult = tr_2[tr_2['Age_Group'] == 'Young Adult']

# %%
young_adult_count1 = (young_adult['Pclass'] == 1).sum()
print(young_adult_count1)
young_adult_rate = young_adult_count1/Young_Adult_count
yac = young_adult_rate.round(2)
print (yac)
# Out:
# 35
# 0.37

# %%
young_adult_count2 = (young_adult['Pclass'] == 2).sum()
print(young_adult_count2)
young_adult_rate2 = young_adult_count2/Young_Adult_count
yac2 = young_adult_rate2.round(2)
print (yac2)
# Out:
# 37
# 0.39

# %%
young_adult_count3 = (young_adult['Pclass'] == 3).sum()
print(young_adult_count3)
young_adult_rate3 = young_adult_count3/Young_Adult_count
yac3 = young_adult_rate3.round(2)
print (yac3)
# Out:
# 22
# 0.23

# %% [markdown]
# from the code above we can infer that young adult women between the ages of 18 and 35 who are in the second socio-economic class are the most likely to survive.
